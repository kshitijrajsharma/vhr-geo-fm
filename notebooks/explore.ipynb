# %%
import pandas as pd

# %%
vhr_datasets= pd.read_csv("../data/vhr_datasets.csv")

# %%
vhr_datasets
# Out:
#              Dataset                   Task               Domain  \
# 0          TreeSatAI         Classification         Tree Species
# 1   Dynamic EarthNet  Semantic Segmentation      LULC (temporal)
# 2            FLAIR 2  Semantic Segmentation                 LULC
# 3         SpaceNet 2  Semantic Segmentation             Building
# 4         SpaceNet 7  Semantic Segmentation             Building
# 5          EverWatch       Object Detection         Bird species
# 6         m-nzcattle       Object Detection               Cattle
# 7            Potsdam  Semantic Segmentation                Urban
# 8          Vaihingen  Semantic Segmentation                Urban
# 9          DOTA V1.0       Object Detection       Aerial Objects
# 10            xView2       Change Detection      Disaster / HADR
# 11          LEVIR-CD       Change Detection             Building
# 12          UCMerced         Classification             Land Use
# ...

# %%
# git clone https://github.com/The-AI-Alliance/GEO-Bench-2-Leaderboard.git

# %%
from pandas.core.frame import DataFrame
vhr_base: DataFrame = pd.read_csv("../data/geo-bench2-results-vhr-base.csv")
vhr_extra: DataFrame = pd.read_csv("../data/geo-bench2-results-vhr-extra.csv")

# %%
vhr_extra
# Out:
#     Rank                      Model          Category # Params Submission  \
# 0      1   ConvNext-XLarge-ImageNet     CV-General-FM     390M   114be1f0
# 1      2  DinoV3-ConvNext-Large-WEB     CV-General-FM     230M   114be1f0
# 2      3           DinoV3-ViT-L-SAT  Native-VHR-GeoFM     300M   114be1f0
# 3      4    ConvNext-Large-ImageNet     CV-General-FM     230M   114be1f0
# 4      5              DOFA-ViT 300M  Native-VHR-GeoFM     300M   114be1f0
# 5      6              DOFA-ViT 300M  Native-VHR-GeoFM     300M   2ce4a907
# 6      7              Clay-V1 ViT-B  Native-VHR-GeoFM     100M   114be1f0
# 7      8              Clay-V1 ViT-B  Native-VHR-GeoFM     100M   2ce4a907
# 8      9         TerraMind-V1-Large      GeoFM-LowRes     300M   114be1f0
# 9     10         TerraMind-V1-Large      GeoFM-LowRes     300M   2ce4a907
# 10    11          Satlas-SwinB-Naip  Native-VHR-GeoFM     100M   114be1f0
# 11    12           Satlas-Swin 100M      GeoFM-LowRes     100M   114be1f0
# ...
